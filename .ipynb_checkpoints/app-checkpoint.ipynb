# %% [markdown]
# # 1-Import Libs / DataSet

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
house_df =pd.read_csv('kc_house_data.csv')

# %%
house_df.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
house_df.tail(5)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view     ...      grade  \
# 21608         1530      1131     3.0           0     0     ...          8
# 21609         2310      5813     2.0           0     0     ...          8
# 21610         1020      1350     2.0           0     0     ...          7
# 21611         1600      2388     2.0           0     0     ...          8
# 21612         1020      1076     2.0           0     0     ...          7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# ...

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# ...

# %%
house_df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
house_df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# # 2-Visualize

# %%
sns.scatterplot(x='bedrooms', y='price', data=house_df)

# %%
sns.scatterplot(x='sqft_living', y='price', data=house_df)

# %%
sns.scatterplot(x='sqft_lot', y='price', data=house_df)

# %%
house_df.hist(bins=20, figsize=(20, 20), color='r')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000137A2A20>,
# ...
#       dtype=object)

# %%
f, ax =plt.subplots(figsize=(20, 20))
sns.heatmap(house_df.corr(), annot=True)

# %%
house_samples =['price','bedrooms','bathrooms','sqft_living', 'sqft_lot', 'sqft_above','sqft_basement', 'yr_built']

# %%
sns.pairplot(house_df[house_samples])

# %% [markdown]
# # 3 - Training the data

# %%
X =house_df.drop(['id', 'date', 'price'], axis=1)
y =house_df['price']

# %%
print(X.shape)
print(y.shape)
# Out:
# (21613, 18)
# (21613,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(X, y, test_size=0.25)

# %%
from sklearn.linear_model import LinearRegression
lr_model =LinearRegression(fit_intercept=True)
lr_model.fit(X_train, y_train)
print('Linear Model Coeff (m)', lr_model.coef_)
print('Linear Model Coeff (b)', lr_model.intercept_)
# Out:
# Linear Model Coeff (m) [-3.52526072e+04  3.66668227e+04  1.13572748e+02  1.31648304e-01
#   7.44851917e+03  5.06862571e+05  5.31106161e+04  2.67007184e+04
#   9.57351495e+04  6.97388755e+01  4.38338729e+01 -2.58382554e+03
#   2.16524753e+01 -5.72773907e+02  5.96080027e+05 -2.12548344e+05
#   2.37515908e+01 -3.76114413e-01]
# Linear Model Coeff (b) 6252644.300698739

# %% [markdown]
# # 4-Evaluate the model

# %%
y_predict =lr_model.predict(X_test)
y_predict
# Out:
# array([466974.6210484 , 657292.61268096, 463285.34972462, ...,
#        629053.35389608, 344784.80007949, 198954.26846479])

# %%
plt.plot(y_test, y_predict, '^', color='r')
plt.xlim(0, 3000000)
plt.ylim(0, 3000000)
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
plt.title('Linear Regression Predictions')
plt.show()

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

# %%
k =X_test.shape[1]
n =len(X_test)

RMSE =float(format(np.sqrt(mean_squared_error(y_test, y_predict)), '.3f'))
MSE =mean_squared_error(y_test, y_predict)
MAE =mean_absolute_error(y_test, y_predict)
r2 =r2_score(y_test, y_predict)
r2_adjusted =1-(1-r2)*(n-1)/(n-k-1)

# %%
print('RMSE = ', RMSE)
print('MSE = ', MSE)
print('MAE = ', MAE)
print('r2 = ', r2)
print('r2_adjusted = ', r2_adjusted)
# Out:
# RMSE =  196511.683
# MSE =  38616841524.41205
# MAE =  125238.01489325805
# r2 =  0.7123165282057613
# r2_adjusted =  0.7113549121440536

# %% [markdown]
# # 5 - Lasso Regression

# %%
from sklearn.linear_model import Lasso
lasso_regressor =Lasso(alpha=50)
lasso_regressor.fit(X_train, y_train)
print('Linear Model Coeff (m)', lasso_regressor.coef_)
print('Linear Model Coeff (b)', lasso_regressor.intercept_)
# Out:
# Linear Model Coeff (m) [-3.51995918e+04  3.64993240e+04  2.87684041e+02  1.29519526e-01
#   7.38387761e+03  4.99329587e+05  5.33738506e+04  2.65208526e+04
#   9.58674466e+04 -1.04343327e+02 -1.30013839e+02 -2.59017750e+03
#   2.17209735e+01 -5.65903960e+02  5.92849450e+05 -2.08109036e+05
#   2.35981762e+01 -3.78245723e-01]
# Linear Model Coeff (b) 6287662.082724836
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
y_predict =lasso_regressor.predict(X_test)
y_predict
# Out:
# array([468499.50039269, 656732.11390809, 463008.47930296, ...,
#        629888.43274253, 344205.01700441, 199854.81901498])

# %%
plt.plot(y_test, y_predict, '^', color='r')
plt.xlim(0, 3000000)
plt.ylim(0, 3000000)
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
plt.title('Linear Regression Predictions')
plt.show()

# %%
k =X_test.shape[1]
n =len(X_test)

RMSE =float(format(np.sqrt(mean_squared_error(y_test, y_predict)), '.3f'))
MSE =mean_squared_error(y_test, y_predict)
MAE =mean_absolute_error(y_test, y_predict)
r2 =r2_score(y_test, y_predict)
r2_adjusted =1-(1-r2)*(n-1)/(n-k-1)

# %%
print('RMSE = ', RMSE)
print('MSE = ', MSE)
print('MAE = ', MAE)
print('r2 = ', r2)
print('r2_adjusted = ', r2_adjusted)
# Out:
# RMSE =  196603.209
# MSE =  38652821647.80654
# MAE =  125220.7166858106
# r2 =  0.7120484874648537
# r2_adjusted =  0.7110859754452377

# %% [markdown]
# # 6 - Ridge Regression

# %%
from sklearn.linear_model import Ridge
ridge_regressor =Ridge(alpha=50)
ridge_regressor.fit(X_train, y_train)
print('Linear Model Coeff (m)', ridge_regressor.coef_)
print('Linear Model Coeff (b)', ridge_regressor.intercept_)
# Out:
# Linear Model Coeff (m) [-3.63313706e+04  3.67617270e+04  1.14233714e+02  9.17552321e-02
#   1.10870136e+04  3.40130472e+05  5.93386679e+04  2.54661816e+04
#   9.89775651e+04  6.73928883e+01  4.68408706e+01 -2.74295326e+03
#   2.24207427e+01 -4.65889775e+02  4.98523399e+05 -1.62703376e+05
#   2.27253666e+01 -3.96366370e-01]
# Linear Model Coeff (b) 6796812.589691769

# %%
y_predict =ridge_regressor.predict(X_test)
y_predict
# Out:
# array([481271.72483882, 647501.57080833, 450258.98599675, ...,
#        645850.85975086, 329844.90213131, 219668.65550643])

# %%
plt.plot(y_test, y_predict, '^', color='r')
plt.xlim(0, 3000000)
plt.ylim(0, 3000000)
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
plt.title('Linear Regression Predictions')
plt.show()

# %%
k =X_test.shape[1]
n =len(X_test)

RMSE =float(format(np.sqrt(mean_squared_error(y_test, y_predict)), '.3f'))
MSE =mean_squared_error(y_test, y_predict)
MAE =mean_absolute_error(y_test, y_predict)
r2 =r2_score(y_test, y_predict)
r2_adjusted =1-(1-r2)*(n-1)/(n-k-1)

# %%
print('RMSE = ', RMSE)
print('MSE = ', MSE)
print('MAE = ', MAE)
print('r2 = ', r2)
print('r2_adjusted = ', r2_adjusted)
# Out:
# RMSE =  199214.743
# MSE =  39686513745.15378
# MAE =  125515.65720824288
# r2 =  0.7043478024892807
# r2_adjusted =  0.7033595500184928
